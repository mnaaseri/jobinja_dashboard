# %%
import requests
from bs4 import BeautifulSoup
import json

# URL of the web page
url = "https://jobinja.ir/companies/pardis-oil-motor/jobs/C1qV/%D8%A7%D8%B3%D8%AA%D8%AE%D8%AF%D8%A7%D9%85-%DA%A9%D8%A7%D8%B1%D8%B4%D9%86%D8%A7%D8%B3-%D8%B5%D8%A7%D8%AF%D8%B1%D8%A7%D8%AA-%D8%AE%D8%A7%D8%B1%D8%AC%DB%8C-%D8%AE%D8%A7%D9%86%D9%85-%D8%AF%D8%B1-%D8%B1%D9%88%D8%BA%D9%86-%D9%85%D9%88%D8%AA%D9%88%D8%B1-%D9%BE%D8%B1%D8%AF%D9%8A%D8%B3?_ref=5"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the JSON part in the HTML source
    json_script = soup.find('script', {"type": "application/ld+json"})

    if json_script:
        # Extract the JSON data
        json_data = json_script.string
        parsed_json = json.loads(json_data)
        date_posted = parsed_json.get("datePosted")
        print(date_posted)
# Out:
# 2023-09-12

# %%
import pandas as pd

# %%
df = pd.read_csv("./Jobinja - Processed.csv")

# %%
df.head()
# Out:
#                                         Job Position  \
# 0               استخدام کارشناس بازرگانی خارجی(خانم)
# 1                             استخدام مدیر بازاریابی
# 2                استخدام کارشناس ارشد حسابداری (آقا)
# 3                     استخدام  برنامه‌نویسNET. (آقا)
# 4  استخدام کارشناس پشتیبانی فنی نرم‌افزار (دانش ب...
#
#                     Job Category Job Location Employment Type      Experience  \
# 0                خرید و بازرگانی        تهران        تمام وقت    سه تا شش سال
# 1               فروش و بازاریابی        تهران        تمام وقت   بیش از شش سال
# 2                مالی و حسابداری        تهران        تمام وقت   بیش از شش سال
# 3  وب،‌ برنامه‌نویسی و نرم‌افزار        تهران        تمام وقت    سه تا شش سال
# 4  وب،‌ برنامه‌نویسی و نرم‌افزار        تهران        تمام وقت  کمتر از سه سال
#
#                 Salary     Company Name                    Company Category  \
# 0  از ۱۲,۰۰۰,۰۰۰ تومان    نخ ریسان بهشت                     واردات و صادرات
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# Sample DataFrame with job URLs
data = {'Job URL': df['Job URL']}

# df = pd.DataFrame(data)

def extract_date_from_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        json_script = soup.find('script', {"type": "application/ld+json"})
        if json_script:
            try:
                json_data = json.loads(json_script.string)
                date_posted = json_data.get("datePosted")
                return date_posted
            except json.JSONDecodeError:
                return None
    return None

df['Date Posted'] = df['Job URL'].apply(extract_date_from_url)
print(df)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1011         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %%
df.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_453970/2522960898.py in <module>
# ----> 1 df.head(50)
#
# NameError: name 'df' is not defined

# %%
df.to_csv("/jobinja_with_date.csv")
